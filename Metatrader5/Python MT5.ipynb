# %% [markdown]
# # Trade with Python through MetaTrader5

# %%
# documentation: https://www.mql5.com/en/docs/integration/python_metatrader5

import MetaTrader5 as mt  # pip install MetaTrader5
import pandas as pd  # pip install pandas
import plotly.express as px  # pip install plotly
from datetime import datetime

# %%
# start the platform with initialize()
mt.initialize()
# Out:
# True

# %%
# login to Trade Account with login()
# make sure that trade server is enabled in MT5 client terminal

login = 50690110
password = 'WaqabMCi'
server = 'ICMarketsSC-Demo'

mt.login(login, password, server)
# Out:
# False

# %%
# get account info
account_info = mt.account_info()
print(account_info)

# getting specific account data
login_number = account_info.login
balance = account_info.balance
equity = account_info.equity

print()
print('login: ', login_number)
print('balance: ', balance)
print('equity: ', equity)
# Out:
# AccountInfo(login=50690110, trade_mode=0, leverage=500, limit_orders=200, margin_so_mode=0, trade_allowed=True, trade_expert=True, margin_mode=2, currency_digits=2, fifo_close=False, balance=99914.0, credit=0.0, profit=8.0, equity=99922.0, margin=464.7, margin_free=99457.3, margin_level=21502.474714869808, margin_so_call=100.0, margin_so_so=50.0, margin_initial=0.0, margin_maintenance=0.0, assets=0.0, liabilities=0.0, commission_blocked=0.0, name='Nguyen Khac Tu', server='ICMarketsSC-Demo', currency='USD', company='Raw Trading Ltd')
#
# login:  50690110
# balance:  99914.0
# equity:  99922.0

# %%
# get number of symbols with symbols_total()
num_symbols = mt.symbols_total()

num_symbols
# Out:
# 0

# %%
# get all symbols and their specifications
symbols = mt.symbols_get()
symbols
# Out:
# (SymbolInfo(custom=False, chart_mode=0, select=True, visible=True, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=1633399852, digits=5, spread=0, spread_float=True, ticks_bookdepth=10, trade_calc_mode=0, trade_mode=4, start_time=0, expiration_time=0, trade_stops_level=0, trade_freeze_level=0, trade_exemode=2, swap_mode=1, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=15, filling_mode=2, order_mode=127, order_gtc_mode=0, option_mode=0, option_right=0, bid=1.1617899999999999, bidhigh=1.16221, bidlow=1.1616, ask=1.1617899999999999, askhigh=1.16223, asklow=1.1616, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=1e-05, trade_tick_value=1.0, trade_tick_value_profit=1.0, trade_tick_value_loss=1.0, trade_tick_size=1e-05, trade_contract_size=100000.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=0.01, volume_max=200.0, volume_step=0.01, volume_limit=0.0, swap_long=-4.5, swap_short=-0.06, margin_initial=100000.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=1.16204, session_close=1.16196, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=0.0, price_change=-0.0146, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='EUR', currency_profit='USD', currency_margin='EUR', bank='', description='Euro vs US Dollar', exchange='', formula='', isin='', name='EURUSD', page='', path='Forex\\Majors\\EURUSD'),
#  SymbolInfo(custom=False, chart_mode=0, select=True, visible=True, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=1633399819, digits=5, spread=6, spread_float=True, ticks_bookdepth=10, trade_calc_mode=0, trade_mode=4, start_time=0, expiration_time=0, trade_stops_level=0, trade_freeze_level=0, trade_exemode=2, swap_mode=1, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=15, filling_mode=2, order_mode=127, order_gtc_mode=0, option_mode=0, option_right=0, bid=1.361, bidhigh=1.36128, bidlow=1.36026, ask=1.36106, askhigh=1.36176, asklow=1.36051, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=1e-05, trade_tick_value=1.0, trade_tick_value_profit=1.0, trade_tick_value_loss=1.0, trade_tick_size=1e-05, trade_contract_size=100000.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=0.01, volume_max=200.0, volume_step=0.01, volume_limit=0.0, swap_long=-3.05, swap_short=-2.42, margin_initial=100000.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=1.36044, session_close=1.36076, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=0.0, price_change=0.0176, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='GBP', currency_profit='USD', currency_margin='GBP', bank='', description='Great Britain Pound vs US Dollar', exchange='', formula='', isin='', name='GBPUSD', page='', path='Forex\\Majors\\GBPUSD'),
#  SymbolInfo(custom=False, chart_mode=0, select=True, visible=True, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=1633399857, digits=5, spread=4, spread_float=True, ticks_bookdepth=10, trade_calc_mode=0, trade_mode=4, start_time=0, expiration_time=0, trade_stops_level=0, trade_freeze_level=0, trade_exemode=2, swap_mode=1, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=15, filling_mode=2, order_mode=127, order_gtc_mode=0, option_mode=0, option_right=0, bid=0.92457, bidhigh=0.92484, bidlow=0.92381, ask=0.92461, askhigh=0.92609, asklow=0.92405, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=1e-05, trade_tick_value=1.0815370804988051, trade_tick_value_profit=1.0815370804988051, trade_tick_value_loss=1.0815838714213093, trade_tick_size=1e-05, trade_contract_size=100000.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=0.01, volume_max=200.0, volume_step=0.01, volume_limit=0.0, swap_long=0.39, swap_short=-4.68, margin_initial=100000.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=0.92475, session_close=0.92454, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=0.0, price_change=0.0032, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='USD', currency_profit='CHF', currency_margin='USD', bank='', description='US Dollar vs Swiss Franc', exchange='', formula='', isin='', name='USDCHF', page='', path='Forex\\Majors\\USDCHF'),
#  SymbolInfo(custom=False, chart_mode=0, select=True, visible=True, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=1633399854, digits=3, spread=1, spread_float=True, ticks_bookdepth=10, trade_calc_mode=0, trade_mode=4, start_time=0, expiration_time=0, trade_stops_level=0, trade_freeze_level=0, trade_exemode=2, swap_mode=1, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=15, filling_mode=2, order_mode=127, order_gtc_mode=0, option_mode=0, option_right=0, bid=110.956, bidhigh=111.0, bidlow=110.841, ask=110.957, askhigh=111.001, asklow=110.911, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=0.001, trade_tick_value=0.9012500337968764, trade_tick_value_profit=0.9012500337968764, trade_tick_value_loss=0.9012581563863153, trade_tick_size=0.001, trade_contract_size=100000.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=0.01, volume_max=200.0, volume_step=0.01, volume_limit=0.0, swap_long=-1.39, swap_short=-3.3, margin_initial=100000.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=110.92, session_close=110.92, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=0.0, price_change=0.0325, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='USD', currency_profit='JPY', currency_margin='USD', bank='', description='US Dollar vs Japanese Yen', exchange='', formula='', isin='', name='USDJPY', page='', path='Forex\\Majors\\USDJPY'),
#  SymbolInfo(custom=False, chart_mode=0, select=True, visible=True, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=1633399843, digits=5, spread=4, spread_float=True, ticks_bookdepth=10, trade_calc_mode=0, trade_mode=4, start_time=0, expiration_time=0, trade_stops_level=0, trade_freeze_level=0, trade_exemode=2, swap_mode=1, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=15, filling_mode=2, order_mode=127, order_gtc_mode=0, option_mode=0, option_right=0, bid=1.25862, bidhigh=1.25892, bidlow=1.2583, ask=1.25866, askhigh=1.2595100000000001, asklow=1.25852, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=1e-05, trade_tick_value=0.7944957335579109, trade_tick_value_profit=0.7944957335579109, trade_tick_value_loss=0.794520983299169, trade_tick_size=1e-05, trade_contract_size=100000.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=0.01, volume_max=200.0, volume_step=0.01, volume_limit=0.0, swap_long=-2.7, swap_short=-2.42, margin_initial=100000.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=1.2588599999999999, session_close=1.25878, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=0.0, price_change=-0.0127, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='USD', currency_profit='CAD', currency_margin='USD', bank='', description='US Dollar vs Canadian Dollar', exchange='', formula='', isin='', name='USDCAD', page='', path='Forex\\Majors\\USDCAD'),
#  SymbolInfo(custom=False, chart_mode=0, select=True, visible=True, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=1633399849, digits=5, spread=0, spread_float=True, ticks_bookdepth=10, trade_calc_mode=0, trade_mode=4, start_time=0, expiration_time=0, trade_stops_level=0, trade_freeze_level=0, trade_exemode=2, swap_mode=1, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=15, filling_mode=2, order_mode=127, order_gtc_mode=0, option_mode=0, option_right=0, bid=0.72925, bidhigh=0.7294, bidlow=0.72769, ask=0.72925, askhigh=0.72945, asklow=0.72869, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=1e-05, trade_tick_value=1.0, trade_tick_value_profit=1.0, trade_tick_value_loss=1.0, trade_tick_size=1e-05, trade_contract_size=100000.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=0.01, volume_max=200.0, volume_step=0.01, volume_limit=0.0, swap_long=-2.12, swap_short=-1.48, margin_initial=100000.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=0.72833, session_close=0.72882, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=0.0, price_change=0.059, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='AUD', currency_profit='USD', currency_margin='AUD', bank='', description='Australian Dollar vs US Dollar', exchange='', formula='', isin='', name='AUDUSD', page='', path='Forex\\Majors\\AUDUSD'),
#  SymbolInfo(custom=False, chart_mode=0, select=True, visible=True, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=1633399845, digits=5, spread=10, spread_float=True, ticks_bookdepth=10, trade_calc_mode=0, trade_mode=4, start_time=0, expiration_time=0, trade_stops_level=0, trade_freeze_level=0, trade_exemode=2, swap_mode=1, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=15, filling_mode=2, order_mode=127, order_gtc_mode=0, option_mode=0, option_right=0, bid=1.04688, bidhigh=1.04702, bidlow=1.04474, ask=1.04698, askhigh=1.04804, asklow=1.04594, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=1e-05, trade_tick_value=0.69653, trade_tick_value_profit=0.69653, trade_tick_value_loss=0.6965700000000001, trade_tick_size=1e-05, trade_contract_size=100000.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=0.01, volume_max=100.0, volume_step=0.01, volume_limit=0.0, swap_long=-2.94, swap_short=-2.12, margin_initial=100000.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=1.04506, session_close=1.0462, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=0.0, price_change=0.065, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='AUD', currency_profit='NZD', currency_margin='AUD', bank='', description='Australian Dollar vs New Zealand Dollar', exchange='', formula='', isin='', name='AUDNZD', page='', path='Forex\\Minors\\AUDNZD'),
#  SymbolInfo(custom=False, chart_mode=0, select=True, visible=True, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=1633399861, digits=5, spread=10, spread_float=True, ticks_bookdepth=10, trade_calc_mode=0, trade_mode=4, start_time=0, expiration_time=0, trade_stops_level=0, trade_freeze_level=0, trade_exemode=2, swap_mode=1, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=15, filling_mode=2, order_mode=127, order_gtc_mode=0, option_mode=0, option_right=0, bid=0.91782, bidhigh=0.91811, bidlow=0.91632, ask=0.91792, askhigh=0.91842, asklow=0.91732, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=1e-05, trade_tick_value=0.7944957335579109, trade_tick_value_profit=0.7944957335579109, trade_tick_value_loss=0.794520983299169, trade_tick_size=1e-05, trade_contract_size=100000.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=0.01, volume_max=100.0, volume_step=0.01, volume_limit=0.0, swap_long=-3.09, swap_short=-1.91, margin_initial=100000.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=0.91643, session_close=0.9174, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=0.0, price_change=0.0458, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='AUD', currency_profit='CAD', currency_margin='AUD', bank='', description='Australian Dollar vs Canadian Dollar', exchange='', formula='', isin='', name='AUDCAD', page='', path='Forex\\Minors\\AUDCAD'),
#  SymbolInfo(custom=False, chart_mode=0, select=True, visible=True, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=1633399865, digits=5, spread=8, spread_float=True, ticks_bookdepth=10, trade_calc_mode=0, trade_mode=4, start_time=0, expiration_time=0, trade_stops_level=0, trade_freeze_level=0, trade_exemode=2, swap_mode=1, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=15, filling_mode=2, order_mode=127, order_gtc_mode=0, option_mode=0, option_right=0, bid=0.6742, bidhigh=0.67441, bidlow=0.67301, ask=0.67428, askhigh=0.67505, asklow=0.67352, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=1e-05, trade_tick_value=1.0815370804988051, trade_tick_value_profit=1.0815370804988051, trade_tick_value_loss=1.0815838714213093, trade_tick_size=1e-05, trade_contract_size=100000.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=0.01, volume_max=100.0, volume_step=0.01, volume_limit=0.0, swap_long=-0.05, swap_short=-3.7, margin_initial=100000.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=0.67356, session_close=0.67383, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=0.0, price_change=0.0549, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='AUD', currency_profit='CHF', currency_margin='AUD', bank='', description='Australian Dollar vs Swiss Franc', exchange='', formula='', isin='', name='AUDCHF', page='', path='Forex\\Minors\\AUDCHF'),
#  SymbolInfo(custom=False, chart_mode=0, select=True, visible=True, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=1633399865, digits=3, spread=5, spread_float=True, ticks_bookdepth=10, trade_calc_mode=0, trade_mode=4, start_time=0, expiration_time=0, trade_stops_level=0, trade_freeze_level=0, trade_exemode=2, swap_mode=1, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=15, filling_mode=2, order_mode=127, order_gtc_mode=0, option_mode=0, option_right=0, bid=80.912, bidhigh=80.948, bidlow=80.73, ask=80.917, askhigh=80.955, asklow=80.832, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=0.001, trade_tick_value=0.9012500337968764, trade_tick_value_profit=0.9012500337968764, trade_tick_value_loss=0.9012581563863153, trade_tick_size=0.001, trade_contract_size=100000.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=0.01, volume_max=100.0, volume_step=0.01, volume_limit=0.0, swap_long=-1.62, swap_short=-2.44, margin_initial=100000.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=80.73, session_close=80.841, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=0.0, price_change=0.0878, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='AUD', currency_profit='JPY', currency_margin='AUD', bank='', description='Australian Dollar vs Japanese Yen', exchange='', formula='', isin='', name='AUDJPY', page='', path='Forex\\Minors\\AUDJPY'),
#  SymbolInfo(custom=False, chart_mode=0, select=True, visible=True, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=1633399857, digits=3, spread=8, spread_float=True, ticks_bookdepth=10, trade_calc_mode=0, trade_mode=4, start_time=0, expiration_time=0, trade_stops_level=0, trade_freeze_level=0, trade_exemode=2, swap_mode=1, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=15, filling_mode=2, order_mode=127, order_gtc_mode=0, option_mode=0, option_right=0, bid=120.004, bidhigh=120.055, bidlow=119.602, ask=120.012, askhigh=120.097, asklow=119.887, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=0.001, trade_tick_value=0.9012500337968764, trade_tick_value_profit=0.9012500337968764, trade_tick_value_loss=0.9012581563863153, trade_tick_size=0.001, trade_contract_size=100000.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=0.01, volume_max=100.0, volume_step=0.01, volume_limit=0.0, swap_long=-5.11, swap_short=-0.68, margin_initial=100000.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=119.819, session_close=119.967, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=0.0, price_change=0.0308, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='CHF', currency_profit='JPY', currency_margin='CHF', bank='', description='Swiss Franc vs Japanese Yen', exchange='', formula='', isin='', name='CHFJPY', page='', path='Forex\\Minors\\CHFJPY'),
#  SymbolInfo(custom=False, chart_mode=0, select=True, visible=True, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=1633399843, digits=5, spread=6, spread_float=True, ticks_bookdepth=10, trade_calc_mode=0, trade_mode=4, start_time=0, expiration_time=0, trade_stops_level=0, trade_freeze_level=0, trade_exemode=2, swap_mode=1, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=15, filling_mode=2, order_mode=127, order_gtc_mode=0, option_mode=0, option_right=0, bid=0.85353, bidhigh=0.85383, bidlow=0.85284, ask=0.85359, askhigh=0.85446, asklow=0.8535, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=1e-05, trade_tick_value=1.3610000000000002, trade_tick_value_profit=1.3610000000000002, trade_tick_value_loss=1.36106, trade_tick_size=1e-05, trade_contract_size=100000.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=0.01, volume_max=100.0, volume_step=0.01, volume_limit=0.0, swap_long=-3.29, swap_short=-0.48, margin_initial=100000.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=0.8536, session_close=0.85377, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=0.0, price_change=-0.0281, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='EUR', currency_profit='GBP', currency_margin='EUR', bank='', description='Euro vs Great Britain Pound', exchange='', formula='', isin='', name='EURGBP', page='', path='Forex\\Minors\\EURGBP'),
#  SymbolInfo(custom=False, chart_mode=0, select=True, visible=True, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=1633399865, digits=5, spread=15, spread_float=True, ticks_bookdepth=10, trade_calc_mode=0, trade_mode=4, start_time=0, expiration_time=0, trade_stops_level=0, trade_freeze_level=0, trade_exemode=2, swap_mode=1, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=15, filling_mode=2, order_mode=127, order_gtc_mode=0, option_mode=0, option_right=0, bid=1.5930499999999999, bidhigh=1.59469, bidlow=1.5925500000000001, ask=1.5932, askhigh=1.5967099999999999, asklow=1.59268, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=1e-05, trade_tick_value=0.72925, trade_tick_value_profit=0.72925, trade_tick_value_loss=0.72925, trade_tick_size=1e-05, trade_contract_size=100000.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=0.01, volume_max=100.0, volume_step=0.01, volume_limit=0.0, swap_long=-6.71, swap_short=-1.16, margin_initial=100000.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=1.5936599999999999, session_close=1.59423, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=0.0, price_change=-0.074, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='EUR', currency_profit='AUD', currency_margin='EUR', bank='', description='Euro vs Australian Dollar', exchange='', formula='', isin='', name='EURAUD', page='', path='Forex\\Minors\\EURAUD'),
#  SymbolInfo(custom=False, chart_mode=0, select=True, visible=True, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=1633399843, digits=5, spread=13, spread_float=True, ticks_bookdepth=10, trade_calc_mode=0, trade_mode=4, start_time=0, expiration_time=0, trade_stops_level=0, trade_freeze_level=0, trade_exemode=2, swap_mode=1, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=15, filling_mode=2, order_mode=127, order_gtc_mode=0, option_mode=0, option_right=0, bid=1.07413, bidhigh=1.07449, bidlow=1.07375, ask=1.07426, askhigh=1.07586, asklow=1.0739, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=1e-05, trade_tick_value=1.0815370804988051, trade_tick_value_profit=1.0815370804988051, trade_tick_value_loss=1.0815838714213093, trade_tick_size=1e-05, trade_contract_size=100000.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=0.01, volume_max=100.0, volume_step=0.01, volume_limit=0.0, swap_long=-1.88, swap_short=-2.91, margin_initial=100000.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=1.07449, session_close=1.07427, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=0.0, price_change=-0.013, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='EUR', currency_profit='CHF', currency_margin='EUR', bank='', description='Euro vs Swiss Franc', exchange='', formula='', isin='', name='EURCHF', page='', path='Forex\\Minors\\EURCHF'),
#  SymbolInfo(custom=False, chart_mode=0, select=True, visible=True, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=1633399854, digits=3, spread=2, spread_float=True, ticks_bookdepth=10, trade_calc_mode=0, trade_mode=4, start_time=0, expiration_time=0, trade_stops_level=0, trade_freeze_level=0, trade_exemode=2, swap_mode=1, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=15, filling_mode=2, order_mode=127, order_gtc_mode=0, option_mode=0, option_right=0, bid=128.907, bidhigh=128.962, bidlow=128.792, ask=128.909, askhigh=128.966, asklow=128.87, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=0.001, trade_tick_value=0.9012500337968764, trade_tick_value_profit=0.9012500337968764, trade_tick_value_loss=0.9012581563863153, trade_tick_size=0.001, trade_contract_size=100000.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=0.01, volume_max=100.0, volume_step=0.01, volume_limit=0.0, swap_long=-3.58, swap_short=-0.88, margin_initial=100000.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=128.872, session_close=128.885, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=0.0, price_change=0.0171, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='EUR', currency_profit='JPY', currency_margin='EUR', bank='', description='Euro vs Japanese Yen', exchange='', formula='', isin='', name='EURJPY', page='', path='Forex\\Minors\\EURJPY'),
#  SymbolInfo(custom=False, chart_mode=0, select=True, visible=True, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=1633399840, digits=5, spread=19, spread_float=True, ticks_bookdepth=10, trade_calc_mode=0, trade_mode=4, start_time=0, expiration_time=0, trade_stops_level=0, trade_freeze_level=0, trade_exemode=2, swap_mode=1, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=15, filling_mode=2, order_mode=127, order_gtc_mode=0, option_mode=0, option_right=0, bid=1.66781, bidhigh=1.66891, bidlow=1.66455, ask=1.6680000000000001, askhigh=1.67144, asklow=1.66738, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=1e-05, trade_tick_value=0.69653, trade_tick_value_profit=0.69653, trade_tick_value_loss=0.6965700000000001, trade_tick_size=1e-05, trade_contract_size=100000.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=0.01, volume_max=100.0, volume_step=0.01, volume_limit=0.0, swap_long=-8.27, swap_short=-0.93, margin_initial=100000.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=1.66615, session_close=1.6678, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=0.0, price_change=0.0006, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='EUR', currency_profit='NZD', currency_margin='EUR', bank='', description='Euro vs New Zealand Dollar', exchange='', formula='', isin='', name='EURNZD', page='', path='Forex\\Minors\\EURNZD'),
#  SymbolInfo(custom=False, chart_mode=0, select=True, visible=True, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=1633399860, digits=5, spread=15, spread_float=True, ticks_bookdepth=10, trade_calc_mode=0, trade_mode=4, start_time=0, expiration_time=0, trade_stops_level=0, trade_freeze_level=0, trade_exemode=2, swap_mode=1, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=15, filling_mode=2, order_mode=127, order_gtc_mode=0, option_mode=0, option_right=0, bid=1.46221, bidhigh=1.46293, bidlow=1.4617200000000001, ask=1.4623599999999999, askhigh=1.4638200000000001, asklow=1.46218, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=1e-05, trade_tick_value=0.7944957335579109, trade_tick_value_profit=0.7944957335579109, trade_tick_value_loss=0.794520983299169, trade_tick_size=1e-05, trade_contract_size=100000.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=0.01, volume_max=100.0, volume_step=0.01, volume_limit=0.0, swap_long=-6.05, swap_short=-0.58, margin_initial=100000.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=1.46273, session_close=1.46266, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=0.0, price_change=-0.0308, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='EUR', currency_profit='CAD', currency_margin='EUR', bank='', description='Euro vs Canadian Dollar', exchange='', formula='', isin='', name='EURCAD', page='', path='Forex\\Minors\\EURCAD'),
#  SymbolInfo(custom=False, chart_mode=0, select=True, visible=True, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=1633399860, digits=5, spread=20, spread_float=True, ticks_bookdepth=10, trade_calc_mode=0, trade_mode=4, start_time=0, expiration_time=0, trade_stops_level=0, trade_freeze_level=0, trade_exemode=2, swap_mode=1, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=15, filling_mode=2, order_mode=127, order_gtc_mode=0, option_mode=0, option_right=0, bid=1.25837, bidhigh=1.25851, bidlow=1.25747, ask=1.25857, askhigh=1.26033, asklow=1.25777, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=1e-05, trade_tick_value=1.0815370804988051, trade_tick_value_profit=1.0815370804988051, trade_tick_value_loss=1.0815838714213093, trade_tick_size=1e-05, trade_contract_size=100000.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=0.01, volume_max=100.0, volume_step=0.01, volume_limit=0.0, swap_long=-0.27, swap_short=-5.67, margin_initial=100000.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=1.2579099999999999, session_close=1.25811, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=0.0, price_change=0.0207, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='GBP', currency_profit='CHF', currency_margin='GBP', bank='', description='Great Britain Pound vs Swiss Franc', exchange='', formula='', isin='', name='GBPCHF', page='', path='Forex\\Minors\\GBPCHF'),
#  SymbolInfo(custom=False, chart_mode=0, select=True, visible=True, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=1633399860, digits=3, spread=13, spread_float=True, ticks_bookdepth=10, trade_calc_mode=0, trade_mode=4, start_time=0, expiration_time=0, trade_stops_level=0, trade_freeze_level=0, trade_exemode=2, swap_mode=1, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=15, filling_mode=2, order_mode=127, order_gtc_mode=0, option_mode=0, option_right=0, bid=151.014, bidhigh=151.072, bidlow=150.823, ask=151.027, askhigh=151.087, asklow=150.936, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=0.001, trade_tick_value=0.9012500337968764, trade_tick_value_profit=0.9012500337968764, trade_tick_value_loss=0.9012581563863153, trade_tick_size=0.001, trade_contract_size=100000.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=0.01, volume_max=100.0, volume_step=0.01, volume_limit=0.0, swap_long=-2.09, swap_short=-4.76, margin_initial=100000.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=150.923, session_close=150.937, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=0.0, price_change=0.051, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='GBP', currency_profit='JPY', currency_margin='GBP', bank='', description='Great Britain Pound vs Japanese Yen', exchange='', formula='', isin='', name='GBPJPY', page='', path='Forex\\Minors\\GBPJPY'),
#  SymbolInfo(custom=False, chart_mode=0, select=True, visible=True, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=1633399825, digits=5, spread=11, spread_float=True, ticks_bookdepth=10, trade_calc_mode=0, trade_mode=4, start_time=0, expiration_time=0, trade_stops_level=0, trade_freeze_level=0, trade_exemode=2, swap_mode=1, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=15, filling_mode=2, order_mode=127, order_gtc_mode=0, option_mode=0, option_right=0, bid=0.73454, bidhigh=0.73464, bidlow=0.73371, ask=0.73465, askhigh=0.7358, asklow=0.73409, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=1e-05, trade_tick_value=1.0815370804988051, trade_tick_value_profit=1.0815370804988051, trade_tick_value_loss=1.0815838714213093, trade_tick_size=1e-05, trade_contract_size=100000.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=0.01, volume_max=100.0, volume_step=0.01, volume_limit=0.0, swap_long=-0.05, swap_short=-4.29, margin_initial=100000.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=0.73433, session_close=0.7344, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=0.0, price_change=0.0191, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='CAD', currency_profit='CHF', currency_margin='CAD', bank='', description='Canadian Dollar vs Swiss Franc', exchange='', formula='', isin='', name='CADCHF', page='', path='Forex\\Minors\\CADCHF'),
#  SymbolInfo(custom=False, chart_mode=0, select=True, visible=True, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=1633399860, digits=3, spread=7, spread_float=True, ticks_bookdepth=10, trade_calc_mode=0, trade_mode=4, start_time=0, expiration_time=0, trade_stops_level=0, trade_freeze_level=0, trade_exemode=2, swap_mode=1, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=15, filling_mode=2, order_mode=127, order_gtc_mode=0, option_mode=0, option_right=0, bid=88.152, bidhigh=88.182, bidlow=88.016, ask=88.159, askhigh=88.194, asklow=88.107, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=0.001, trade_tick_value=0.9012500337968764, trade_tick_value_profit=0.9012500337968764, trade_tick_value_loss=0.9012581563863153, trade_tick_size=0.001, trade_contract_size=100000.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=0.01, volume_max=100.0, volume_step=0.01, volume_limit=0.0, swap_long=-1.23, swap_short=-2.72, margin_initial=100000.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=88.091, session_close=88.11, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=0.0, price_change=0.0477, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='CAD', currency_profit='JPY', currency_margin='CAD', bank='', description='Canadian Dollar vs Japanese Yen', exchange='', formula='', isin='', name='CADJPY', page='', path='Forex\\Minors\\CADJPY'),
#  SymbolInfo(custom=False, chart_mode=0, select=True, visible=True, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=1633399868, digits=5, spread=20, spread_float=True, ticks_bookdepth=10, trade_calc_mode=0, trade_mode=4, start_time=0, expiration_time=0, trade_stops_level=0, trade_freeze_level=0, trade_exemode=2, swap_mode=1, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=15, filling_mode=2, order_mode=127, order_gtc_mode=0, option_mode=0, option_right=0, bid=1.86629, bidhigh=1.86734, bidlow=1.8654199999999999, ask=1.86649, askhigh=1.8703400000000001, asklow=1.866, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=1e-05, trade_tick_value=0.72925, trade_tick_value_profit=0.72925, trade_tick_value_loss=0.72925, trade_tick_size=1e-05, trade_contract_size=100000.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=0.01, volume_max=100.0, volume_step=0.01, volume_limit=0.0, swap_long=-4.53, swap_short=-5.05, margin_initial=100000.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=1.866, session_close=1.86701, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=0.0, price_change=-0.0386, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='GBP', currency_profit='AUD', currency_margin='GBP', bank='', description='Great Britain Pound vs Australian Dollar', exchange='', formula='', isin='', name='GBPAUD', page='', path='Forex\\Minors\\GBPAUD'),
#  SymbolInfo(custom=False, chart_mode=0, select=True, visible=True, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=1633399860, digits=5, spread=25, spread_float=True, ticks_bookdepth=10, trade_calc_mode=0, trade_mode=4, start_time=0, expiration_time=0, trade_stops_level=0, trade_freeze_level=0, trade_exemode=2, swap_mode=1, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=15, filling_mode=2, order_mode=127, order_gtc_mode=0, option_mode=0, option_right=0, bid=1.71296, bidhigh=1.7134, bidlow=1.71191, ask=1.7132100000000001, askhigh=1.71498, asklow=1.71303, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=1e-05, trade_tick_value=0.7944957335579109, trade_tick_value_profit=0.7944957335579109, trade_tick_value_loss=0.794520983299169, trade_tick_size=1e-05, trade_contract_size=100000.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=0.01, volume_max=100.0, volume_step=0.01, volume_limit=0.0, swap_long=-4.74, swap_short=-3.57, margin_initial=100000.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=1.71293, session_close=1.71293, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=0.0, price_change=0.0018, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='GBP', currency_profit='CAD', currency_margin='GBP', bank='', description='Great Britain Pound vs Canadian Dollar', exchange='', formula='', isin='', name='GBPCAD', page='', path='Forex\\Minors\\GBPCAD'),
#  SymbolInfo(custom=False, chart_mode=0, select=True, visible=True, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=1633399818, digits=5, spread=37, spread_float=True, ticks_bookdepth=10, trade_calc_mode=0, trade_mode=4, start_time=0, expiration_time=0, trade_stops_level=0, trade_freeze_level=0, trade_exemode=2, swap_mode=1, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=15, filling_mode=2, order_mode=127, order_gtc_mode=0, option_mode=0, option_right=0, bid=1.95382, bidhigh=1.95464, bidlow=1.9498, ask=1.95419, askhigh=1.95769, asklow=1.9533, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=1e-05, trade_tick_value=0.69653, trade_tick_value_profit=0.69653, trade_tick_value_loss=0.6965700000000001, trade_tick_size=1e-05, trade_contract_size=100000.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=0.01, volume_max=100.0, volume_step=0.01, volume_limit=0.0, swap_long=-5.7, swap_short=-4.41, margin_initial=100000.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=1.9521, session_close=1.95304, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=0.0, price_change=0.0399, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='GBP', currency_profit='NZD', currency_margin='GBP', bank='', description='Great Britain Pound vs New Zealand Dollar', exchange='', formula='', isin='', name='GBPNZD', page='', path='Forex\\Minors\\GBPNZD'),
#  SymbolInfo(custom=False, chart_mode=0, select=True, visible=True, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=1633399860, digits=5, spread=12, spread_float=True, ticks_bookdepth=10, trade_calc_mode=0, trade_mode=4, start_time=0, expiration_time=0, trade_stops_level=0, trade_freeze_level=0, trade_exemode=2, swap_mode=1, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=15, filling_mode=2, order_mode=127, order_gtc_mode=0, option_mode=0, option_right=0, bid=0.87665, bidhigh=0.87722, bidlow=0.8749, ask=0.87677, askhigh=0.87912, asklow=0.87623, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=1e-05, trade_tick_value=0.7944957335579109, trade_tick_value_profit=0.7944957335579109, trade_tick_value_loss=0.794520983299169, trade_tick_size=1e-05, trade_contract_size=100000.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=0.01, volume_max=100.0, volume_step=0.01, volume_limit=0.0, swap_long=-2.23, swap_short=-2.06, margin_initial=100000.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=0.87639, session_close=0.87674, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=0.0, price_change=-0.0103, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='NZD', currency_profit='CAD', currency_margin='NZD', bank='', description='New Zealand Dollar vs Canadian Dollar', exchange='', formula='', isin='', name='NZDCAD', page='', path='Forex\\Minors\\NZDCAD'),
# ...
#  SymbolInfo(custom=False, chart_mode=0, select=True, visible=True, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=1633388099, digits=3, spread=56, spread_float=True, ticks_bookdepth=0, trade_calc_mode=2, trade_mode=4, start_time=0, expiration_time=0, trade_stops_level=0, trade_freeze_level=0, trade_exemode=2, swap_mode=5, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=15, filling_mode=2, order_mode=127, order_gtc_mode=0, option_mode=0, option_right=0, bid=22.82, bidhigh=23.648, bidlow=22.667, ask=22.876, askhigh=23.772, asklow=22.803, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=0.001, trade_tick_value=0.001, trade_tick_value_profit=0.001, trade_tick_value_loss=0.001, trade_tick_size=0.001, trade_contract_size=1.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=10.0, volume_max=1000.0, volume_step=1.0, volume_limit=1000.0, swap_long=-2.606, swap_short=-2.394, margin_initial=0.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=23.23, session_close=23.665, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=0.0, price_change=-3.5707, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='USD', currency_profit='USD', currency_margin='USD', bank='', description='Livent Corporation', exchange='', formula='', isin='US53814L1089', name='LTHM.NYSE', page='', path="Stock CFD's\\NYSE\\LTHM.NYSE"),
#  SymbolInfo(custom=False, chart_mode=0, select=True, visible=True, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=1633388099, digits=3, spread=26, spread_float=True, ticks_bookdepth=0, trade_calc_mode=2, trade_mode=4, start_time=0, expiration_time=0, trade_stops_level=0, trade_freeze_level=0, trade_exemode=2, swap_mode=5, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=15, filling_mode=2, order_mode=127, order_gtc_mode=0, option_mode=0, option_right=0, bid=8.338, bidhigh=8.779, bidlow=8.26, ask=8.364, askhigh=8.818999999999999, asklow=8.3, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=0.001, trade_tick_value=0.001, trade_tick_value_profit=0.001, trade_tick_value_loss=0.001, trade_tick_size=0.001, trade_contract_size=1.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=10.0, volume_max=1000.0, volume_step=1.0, volume_limit=1000.0, swap_long=-2.606, swap_short=-2.394, margin_initial=0.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=8.657, session_close=8.89, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=0.0, price_change=-6.2092, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='USD', currency_profit='USD', currency_margin='USD', bank='', description='American Well Corp', exchange='', formula='', isin='US03044L1052', name='AMWL.NYSE', page='', path="Stock CFD's\\NYSE\\AMWL.NYSE"),
#  SymbolInfo(custom=False, chart_mode=0, select=True, visible=True, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=1633388099, digits=3, spread=29, spread_float=True, ticks_bookdepth=0, trade_calc_mode=2, trade_mode=4, start_time=0, expiration_time=0, trade_stops_level=0, trade_freeze_level=0, trade_exemode=2, swap_mode=5, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=15, filling_mode=2, order_mode=127, order_gtc_mode=0, option_mode=0, option_right=0, bid=21.775, bidhigh=23.217, bidlow=21.655, ask=21.804, askhigh=23.248, asklow=21.697, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=0.001, trade_tick_value=0.001, trade_tick_value_profit=0.001, trade_tick_value_loss=0.001, trade_tick_size=0.001, trade_contract_size=1.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=10.0, volume_max=1000.0, volume_step=1.0, volume_limit=1000.0, swap_long=-2.606, swap_short=-2.394, margin_initial=0.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=22.466, session_close=22.111, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=0.0, price_change=-1.5196, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='USD', currency_profit='USD', currency_margin='USD', bank='', description='Cameco Corp', exchange='', formula='', isin='', name='CCJ.NYSE', page='', path="Stock CFD's\\NYSE\\CCJ.NYSE"),
#  SymbolInfo(custom=False, chart_mode=0, select=True, visible=True, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=1633388099, digits=3, spread=18, spread_float=True, ticks_bookdepth=0, trade_calc_mode=2, trade_mode=4, start_time=0, expiration_time=0, trade_stops_level=0, trade_freeze_level=0, trade_exemode=2, swap_mode=5, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=15, filling_mode=2, order_mode=127, order_gtc_mode=0, option_mode=0, option_right=0, bid=16.094, bidhigh=16.369, bidlow=16.08, ask=16.112, askhigh=16.399, asklow=16.11, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=0.001, trade_tick_value=0.001, trade_tick_value_profit=0.001, trade_tick_value_loss=0.001, trade_tick_size=0.001, trade_contract_size=1.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=10.0, volume_max=1000.0, volume_step=1.0, volume_limit=1000.0, swap_long=-2.606, swap_short=-2.394, margin_initial=0.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=16.356, session_close=16.407, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=0.0, price_change=-1.9077, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='USD', currency_profit='USD', currency_margin='USD', bank='', description='Takeda Pharmaceutical Company Limited', exchange='', formula='', isin='US8740602052', name='TAK.NYSE', page='', path="Stock CFD's\\NYSE\\TAK.NYSE"),
#  SymbolInfo(custom=False, chart_mode=0, select=True, visible=True, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=1633388090, digits=3, spread=121, spread_float=True, ticks_bookdepth=0, trade_calc_mode=2, trade_mode=4, start_time=0, expiration_time=0, trade_stops_level=0, trade_freeze_level=0, trade_exemode=2, swap_mode=5, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=15, filling_mode=2, order_mode=127, order_gtc_mode=0, option_mode=0, option_right=0, bid=17.486, bidhigh=17.839, bidlow=17.261, ask=17.607, askhigh=18.01, asklow=17.523, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=0.001, trade_tick_value=0.001, trade_tick_value_profit=0.001, trade_tick_value_loss=0.001, trade_tick_size=0.001, trade_contract_size=1.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=10.0, volume_max=1000.0, volume_step=1.0, volume_limit=1000.0, swap_long=-2.606, swap_short=-2.394, margin_initial=0.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=17.352, session_close=17.555, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=0.0, price_change=-0.3931, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='USD', currency_profit='USD', currency_margin='USD', bank='', description='Harsco Corp', exchange='', formula='', isin='US4158641070', name='HSC.NYSE', page='', path="Stock CFD's\\NYSE\\HSC.NYSE"),
#  SymbolInfo(custom=False, chart_mode=0, select=True, visible=True, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=1633388099, digits=3, spread=22, spread_float=True, ticks_bookdepth=0, trade_calc_mode=2, trade_mode=4, start_time=0, expiration_time=0, trade_stops_level=0, trade_freeze_level=0, trade_exemode=2, swap_mode=5, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=15, filling_mode=2, order_mode=127, order_gtc_mode=0, option_mode=0, option_right=0, bid=17.92, bidhigh=18.258, bidlow=17.88, ask=17.942, askhigh=18.334, asklow=17.92, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=0.001, trade_tick_value=0.001, trade_tick_value_profit=0.001, trade_tick_value_loss=0.001, trade_tick_size=0.001, trade_contract_size=1.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=10.0, volume_max=1000.0, volume_step=1.0, volume_limit=1000.0, swap_long=-2.606, swap_short=-2.394, margin_initial=0.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=18.064, session_close=18.096, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=0.0, price_change=-0.9726, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='USD', currency_profit='USD', currency_margin='USD', bank='', description='Piedmont Office Realty Trust I', exchange='', formula='', isin='US7201902068', name='PDM.NYSE', page='', path="Stock CFD's\\NYSE\\PDM.NYSE"),
#  SymbolInfo(custom=False, chart_mode=0, select=True, visible=True, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=1633388098, digits=3, spread=29, spread_float=True, ticks_bookdepth=0, trade_calc_mode=2, trade_mode=4, start_time=0, expiration_time=0, trade_stops_level=0, trade_freeze_level=0, trade_exemode=2, swap_mode=5, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=15, filling_mode=2, order_mode=127, order_gtc_mode=0, option_mode=0, option_right=0, bid=28.649, bidhigh=29.096, bidlow=27.795, ask=28.678, askhigh=29.157, asklow=27.883, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=0.001, trade_tick_value=0.001, trade_tick_value_profit=0.001, trade_tick_value_loss=0.001, trade_tick_size=0.001, trade_contract_size=1.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=10.0, volume_max=1000.0, volume_step=1.0, volume_limit=1000.0, swap_long=-2.606, swap_short=-2.394, margin_initial=0.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=27.96, session_close=27.896, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=0.0, price_change=2.6993, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='USD', currency_profit='USD', currency_margin='USD', bank='', description='SM Energy Co', exchange='', formula='', isin='US78454L1008', name='SM.NYSE', page='', path="Stock CFD's\\NYSE\\SM.NYSE"),
#  SymbolInfo(custom=False, chart_mode=0, select=True, visible=True, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=1633388099, digits=3, spread=17, spread_float=True, ticks_bookdepth=0, trade_calc_mode=2, trade_mode=4, start_time=0, expiration_time=0, trade_stops_level=0, trade_freeze_level=0, trade_exemode=2, swap_mode=5, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=15, filling_mode=2, order_mode=127, order_gtc_mode=0, option_mode=0, option_right=0, bid=16.923000000000002, bidhigh=17.179, bidlow=16.7, ask=16.94, askhigh=17.229, asklow=16.744, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=0.001, trade_tick_value=0.001, trade_tick_value_profit=0.001, trade_tick_value_loss=0.001, trade_tick_size=0.001, trade_contract_size=1.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=10.0, volume_max=1000.0, volume_step=1.0, volume_limit=1000.0, swap_long=-2.606, swap_short=-2.394, margin_initial=0.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=16.852, session_close=16.812, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=0.0, price_change=0.6602, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='USD', currency_profit='USD', currency_margin='USD', bank='', description='Vistra Energy Corp', exchange='', formula='', isin='US92840M1027', name='VST.NYSE', page='', path="Stock CFD's\\NYSE\\VST.NYSE"),
#  ...)

# %%
# get symbol specifications
symbol_info = mt.symbol_info("EURUSD")._asdict()
symbol_info
# Out:
# {'custom': False,
#  'chart_mode': 0,
#  'select': True,
#  'visible': True,
#  'session_deals': 0,
#  'session_buy_orders': 0,
#  'session_sell_orders': 0,
#  'volume': 0,
#  'volumehigh': 0,
#  'volumelow': 0,
#  'time': 1633399942,
#  'digits': 5,
#  'spread': 0,
#  'spread_float': True,
#  'ticks_bookdepth': 10,
#  'trade_calc_mode': 0,
#  'trade_mode': 4,
#  'start_time': 0,
#  'expiration_time': 0,
#  'trade_stops_level': 0,
#  'trade_freeze_level': 0,
#  'trade_exemode': 2,
#  'swap_mode': 1,
#  'swap_rollover3days': 3,
#  'margin_hedged_use_leg': False,
#  'expiration_mode': 15,
#  'filling_mode': 2,
#  'order_mode': 127,
#  'order_gtc_mode': 0,
#  'option_mode': 0,
#  'option_right': 0,
#  'bid': 1.1618,
#  'bidhigh': 1.16221,
#  'bidlow': 1.1616,
#  'ask': 1.1618,
#  'askhigh': 1.16223,
#  'asklow': 1.1616,
#  'last': 0.0,
#  'lasthigh': 0.0,
#  'lastlow': 0.0,
#  'volume_real': 0.0,
#  'volumehigh_real': 0.0,
#  'volumelow_real': 0.0,
#  'option_strike': 0.0,
#  'point': 1e-05,
#  'trade_tick_value': 1.0,
#  'trade_tick_value_profit': 1.0,
#  'trade_tick_value_loss': 1.0,
#  'trade_tick_size': 1e-05,
#  'trade_contract_size': 100000.0,
#  'trade_accrued_interest': 0.0,
#  'trade_face_value': 0.0,
#  'trade_liquidity_rate': 0.0,
#  'volume_min': 0.01,
#  'volume_max': 200.0,
#  'volume_step': 0.01,
#  'volume_limit': 0.0,
#  'swap_long': -4.5,
#  'swap_short': -0.06,
#  'margin_initial': 100000.0,
#  'margin_maintenance': 0.0,
#  'session_volume': 0.0,
#  'session_turnover': 0.0,
#  'session_interest': 0.0,
#  'session_buy_orders_volume': 0.0,
#  'session_sell_orders_volume': 0.0,
#  'session_open': 1.16204,
#  'session_close': 1.16196,
#  'session_aw': 0.0,
#  'session_price_settlement': 0.0,
#  'session_price_limit_min': 0.0,
#  'session_price_limit_max': 0.0,
#  'margin_hedged': 0.0,
#  'price_change': -0.0138,
#  'price_volatility': 0.0,
#  'price_theoretical': 0.0,
#  'price_greeks_delta': 0.0,
#  'price_greeks_theta': 0.0,
#  'price_greeks_gamma': 0.0,
#  'price_greeks_vega': 0.0,
#  'price_greeks_rho': 0.0,
#  'price_greeks_omega': 0.0,
#  'price_sensitivity': 0.0,
#  'basis': '',
#  'category': '',
#  'currency_base': 'EUR',
#  'currency_profit': 'USD',
#  'currency_margin': 'EUR',
#  'bank': '',
#  'description': 'Euro vs US Dollar',
#  'exchange': '',
#  'formula': '',
#  'isin': '',
#  'name': 'EURUSD',
#  'page': '',
#  'path': 'Forex\\Majors\\EURUSD'}

# %%
# get current symbol price
symbol_price = mt.symbol_info_tick("EURUSD")._asdict()
symbol_price
# Out:
# {'time': 1633400050,
#  'bid': 1.16184,
#  'ask': 1.16185,
#  'last': 0.0,
#  'volume': 0,
#  'time_msc': 1633400050604,
#  'flags': 2,
#  'volume_real': 0.0}

# %%
# ohlc_data
ohlc_data = pd.DataFrame(mt.copy_rates_range("EURUSD", 
                                             mt.TIMEFRAME_D1, 
                                             datetime(2021, 1, 1), 
                                             datetime.now()))

fig = px.line(ohlc_data, x=ohlc_data['time'], y=ohlc_data['close'])
fig.show()

ohlc_data
# Out:
#            time     open     high      low    close  tick_volume  spread  \
# 0    1672617600  1.07016  1.07017  1.06499  1.06665        16741       0
# 1    1672704000  1.06642  1.06830  1.05196  1.05470       139201       0
# 2    1672790400  1.05465  1.06354  1.05402  1.06030       140651       0
# 3    1672876800  1.06015  1.06315  1.05150  1.05207       126223       0
# 4    1672963200  1.05205  1.06481  1.04832  1.06427       126014       0
# ..          ...      ...      ...      ...      ...          ...     ...
# 109  1685664000  1.07617  1.07791  1.07052  1.07060        59141       0
# 110  1685923200  1.07071  1.07225  1.06747  1.07125        61925       0
# 111  1686009600  1.07109  1.07329  1.06671  1.06923        50815       0
# 112  1686096000  1.06915  1.07398  1.06683  1.06982        53385       0
# 113  1686182400  1.06975  1.07191  1.06913  1.07123        15940       0
#
#      real_volume
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0
# ..           ...
# 109            0
# 110            0
# 111            0
# 112            0
# 113            0
#
# [114 rows x 8 columns]

# %%
# requesting tick data
tick_data = pd.DataFrame(mt.copy_ticks_range("EURUSD", 
                                             datetime(2021, 10, 4), 
                                             datetime.now(), 
                                             mt.COPY_TICKS_ALL))

fig = px.line(tick_data, x=tick_data['time'], y=[tick_data['bid'], tick_data['ask']])
fig.show()

tick_data
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 7
#       1 # requesting tick data
#       2 tick_data = pd.DataFrame(mt.copy_ticks_range("EURUSD",
#       3                                              datetime(2021, 10, 4),
#       4                                              datetime.now(),
#       5                                              mt.COPY_TICKS_ALL))
# ----> 7 fig = px.line(tick_data, x=tick_data['time'], y=[tick_data['bid'], tick_data['ask']])
#       8 fig.show()
#      10 tick_data
#
# File c:\Users\PC\miniconda3\envs\data\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\PC\miniconda3\envs\data\Lib\site-packages\pandas\core\indexes\range.py:417, in RangeIndex.get_loc(self, key)
#     415         raise KeyError(key) from err
#     416 if isinstance(key, Hashable):
# --> 417     raise KeyError(key)
#     418 self._check_indexing_error(key)
#     419 raise KeyError(key)
#
# KeyError: 'time'

# %%
# total number of orders
num_orders = mt.orders_total()
num_orders
# Out:
# 2

# %%
# list of orders
orders = mt.orders_get()
orders
# Out:
# (TradeOrder(ticket=158627935, time_setup=1633400381, time_setup_msc=1633400381642, time_done=0, time_done_msc=0, time_expiration=0, type=4, type_time=0, type_filling=2, state=1, magic=0, position_id=0, position_by_id=0, reason=0, volume_initial=1.0, volume_current=1.0, price_open=1.19857, sl=0.0, tp=0.0, price_current=1.16184, price_stoplimit=0.0, symbol='EURUSD', comment='', external_id=''),
#  TradeOrder(ticket=158627950, time_setup=1633400384, time_setup_msc=1633400384952, time_done=0, time_done_msc=0, time_expiration=0, type=4, type_time=0, type_filling=2, state=1, magic=0, position_id=0, position_by_id=0, reason=0, volume_initial=1.0, volume_current=1.0, price_open=1.20644, sl=0.0, tp=0.0, price_current=1.16184, price_stoplimit=0.0, symbol='EURUSD', comment='', external_id=''))

# %%
# total number of positions
num_positions = mt.positions_total()
num_positions
# Out:
# 2

# %%
# list of positions
positions = mt.positions_get()
positions
# Out:
# (TradePosition(ticket=158631228, time=1633401105, time_msc=1633401105325, time_update=1633401105, time_update_msc=1633401105325, type=0, magic=234000, identifier=158631228, reason=3, volume=2.0, price_open=1.1617, sl=0.0, tp=0.0, price_current=1.16174, swap=0.0, profit=8.0, symbol='EURUSD', comment='python script op', external_id=''),)

# %%
# number of history orders
num_order_history = mt.history_orders_total(datetime(2021, 1, 1), datetime(2021, 10, 6))
num_order_history
# Out:
# 14

# %%
# list of history orders
order_history = mt.history_orders_get(datetime(2021, 1, 1), datetime(2021, 10, 6))
order_history
# Out:
# (TradeOrder(ticket=158622885, time_setup=1633397636, time_setup_msc=1633397636702, time_done=1633397636, time_done_msc=1633397636955, time_expiration=0, type=0, type_time=0, type_filling=1, state=4, magic=0, position_id=158622885, position_by_id=0, reason=0, volume_initial=1.0, volume_current=0.0, price_open=0.0, sl=0.0, tp=0.0, price_current=1.16199, price_stoplimit=0.0, symbol='EURUSD', comment='', external_id=''),
#  TradeOrder(ticket=158622888, time_setup=1633397639, time_setup_msc=1633397639272, time_done=1633397639, time_done_msc=1633397639524, time_expiration=0, type=1, type_time=0, type_filling=1, state=4, magic=0, position_id=158622888, position_by_id=0, reason=0, volume_initial=1.0, volume_current=0.0, price_open=0.0, sl=0.0, tp=0.0, price_current=1.16198, price_stoplimit=0.0, symbol='EURUSD', comment='', external_id=''),
#  TradeOrder(ticket=158622890, time_setup=1633397640, time_setup_msc=1633397640073, time_done=1633397640, time_done_msc=1633397640325, time_expiration=0, type=1, type_time=0, type_filling=1, state=4, magic=0, position_id=158622890, position_by_id=0, reason=0, volume_initial=1.0, volume_current=0.0, price_open=0.0, sl=0.0, tp=0.0, price_current=1.16198, price_stoplimit=0.0, symbol='EURUSD', comment='', external_id=''),
#  TradeOrder(ticket=158622905, time_setup=1633397640, time_setup_msc=1633397640972, time_done=1633397641, time_done_msc=1633397641224, time_expiration=0, type=0, type_time=0, type_filling=1, state=4, magic=0, position_id=158622905, position_by_id=0, reason=0, volume_initial=1.0, volume_current=0.0, price_open=0.0, sl=0.0, tp=0.0, price_current=1.16199, price_stoplimit=0.0, symbol='EURUSD', comment='', external_id=''),
#  TradeOrder(ticket=158622909, time_setup=1633397642, time_setup_msc=1633397642452, time_done=1633397642, time_done_msc=1633397642711, time_expiration=0, type=1, type_time=0, type_filling=1, state=4, magic=0, position_id=158622905, position_by_id=0, reason=0, volume_initial=1.0, volume_current=0.0, price_open=0.0, sl=0.0, tp=0.0, price_current=1.16198, price_stoplimit=0.0, symbol='EURUSD', comment='', external_id=''),
#  TradeOrder(ticket=158622912, time_setup=1633397643, time_setup_msc=1633397643242, time_done=1633397643, time_done_msc=1633397643495, time_expiration=0, type=0, type_time=0, type_filling=1, state=4, magic=0, position_id=158622890, position_by_id=0, reason=0, volume_initial=1.0, volume_current=0.0, price_open=0.0, sl=0.0, tp=0.0, price_current=1.162, price_stoplimit=0.0, symbol='EURUSD', comment='', external_id=''),
#  TradeOrder(ticket=158622918, time_setup=1633397644, time_setup_msc=1633397644052, time_done=1633397644, time_done_msc=1633397644310, time_expiration=0, type=0, type_time=0, type_filling=1, state=4, magic=0, position_id=158622888, position_by_id=0, reason=0, volume_initial=1.0, volume_current=0.0, price_open=0.0, sl=0.0, tp=0.0, price_current=1.162, price_stoplimit=0.0, symbol='EURUSD', comment='', external_id=''),
#  TradeOrder(ticket=158622935, time_setup=1633397645, time_setup_msc=1633397645692, time_done=1633397645, time_done_msc=1633397645952, time_expiration=0, type=0, type_time=0, type_filling=1, state=4, magic=0, position_id=158622935, position_by_id=0, reason=0, volume_initial=1.0, volume_current=0.0, price_open=0.0, sl=0.0, tp=0.0, price_current=1.16198, price_stoplimit=0.0, symbol='EURUSD', comment='', external_id=''),
#  TradeOrder(ticket=158623407, time_setup=1633397705, time_setup_msc=1633397705543, time_done=1633400368, time_done_msc=1633400368812, time_expiration=0, type=4, type_time=0, type_filling=2, state=2, magic=0, position_id=0, position_by_id=0, reason=0, volume_initial=1.0, volume_current=1.0, price_open=1.16948, sl=0.0, tp=0.0, price_current=1.16183, price_stoplimit=0.0, symbol='EURUSD', comment='', external_id=''),
#  TradeOrder(ticket=158623439, time_setup=1633397710, time_setup_msc=1633397710342, time_done=1633398280, time_done_msc=1633398280532, time_expiration=0, type=5, type_time=0, type_filling=2, state=2, magic=0, position_id=0, position_by_id=0, reason=0, volume_initial=1.0, volume_current=1.0, price_open=1.15126, sl=0.0, tp=0.0, price_current=1.16183, price_stoplimit=0.0, symbol='EURUSD', comment='', external_id=''),
#  TradeOrder(ticket=158624328, time_setup=1633398088, time_setup_msc=1633398088412, time_done=1633398088, time_done_msc=1633398088672, time_expiration=0, type=1, type_time=0, type_filling=1, state=4, magic=0, position_id=158622935, position_by_id=0, reason=0, volume_initial=1.0, volume_current=0.0, price_open=0.0, sl=0.0, tp=0.0, price_current=1.16181, price_stoplimit=0.0, symbol='EURUSD', comment='', external_id=''),
#  TradeOrder(ticket=158625129, time_setup=1633398768, time_setup_msc=1633398768312, time_done=1633398768, time_done_msc=1633398768572, time_expiration=0, type=0, type_time=0, type_filling=1, state=4, magic=234000, position_id=158625129, position_by_id=0, reason=3, volume_initial=2.0, volume_current=0.0, price_open=0.0, sl=0.0, tp=0.0, price_current=1.16175, price_stoplimit=0.0, symbol='EURUSD', comment='python script op', external_id=''),
#  TradeOrder(ticket=158625441, time_setup=1633398962, time_setup_msc=1633398962442, time_done=1633398962, time_done_msc=1633398962694, time_expiration=0, type=1, type_time=0, type_filling=1, state=4, magic=234000, position_id=158622885, position_by_id=0, reason=3, volume_initial=1.0, volume_current=0.0, price_open=0.0, sl=0.0, tp=0.0, price_current=1.16177, price_stoplimit=0.0, symbol='EURUSD', comment='python script op', external_id=''),
#  TradeOrder(ticket=158628089, time_setup=1633400464, time_setup_msc=1633400464332, time_done=1633400464, time_done_msc=1633400464589, time_expiration=0, type=0, type_time=0, type_filling=1, state=4, magic=0, position_id=158628089, position_by_id=0, reason=0, volume_initial=1.0, volume_current=0.0, price_open=0.0, sl=0.0, tp=0.0, price_current=1.1618, price_stoplimit=0.0, symbol='EURUSD', comment='', external_id=''))

# %%
# number of history deals
num_deal_history = mt.history_deals_total(datetime(2021, 1, 1),  datetime(2021, 10, 6))
num_deal_history
# Out:
# 13

# %%
# number of history deals
deal_history = mt.history_deals_get(datetime(2021, 1, 1), datetime(2021, 10, 6))
deal_history
# Out:
# (TradeDeal(ticket=112401396, order=0, time=1633379241, time_msc=1633379241114, type=2, entry=0, magic=0, position_id=0, reason=0, volume=0.0, price=0.0, commission=0.0, swap=0.0, profit=100000.0, fee=0.0, symbol='', comment='Demo deposit', external_id=''),
#  TradeDeal(ticket=112436909, order=158622885, time=1633397636, time_msc=1633397636955, type=0, entry=0, magic=0, position_id=158622885, reason=0, volume=1.0, price=1.16199, commission=-3.5, swap=0.0, profit=0.0, fee=0.0, symbol='EURUSD', comment='', external_id=''),
#  TradeDeal(ticket=112436911, order=158622888, time=1633397639, time_msc=1633397639524, type=1, entry=0, magic=0, position_id=158622888, reason=0, volume=1.0, price=1.16198, commission=-3.5, swap=0.0, profit=0.0, fee=0.0, symbol='EURUSD', comment='', external_id=''),
#  TradeDeal(ticket=112436913, order=158622890, time=1633397640, time_msc=1633397640325, type=1, entry=0, magic=0, position_id=158622890, reason=0, volume=1.0, price=1.16198, commission=-3.5, swap=0.0, profit=0.0, fee=0.0, symbol='EURUSD', comment='', external_id=''),
#  TradeDeal(ticket=112436926, order=158622905, time=1633397641, time_msc=1633397641224, type=0, entry=0, magic=0, position_id=158622905, reason=0, volume=1.0, price=1.16199, commission=-3.5, swap=0.0, profit=0.0, fee=0.0, symbol='EURUSD', comment='', external_id=''),
#  TradeDeal(ticket=112436930, order=158622909, time=1633397642, time_msc=1633397642711, type=1, entry=1, magic=0, position_id=158622905, reason=0, volume=1.0, price=1.16198, commission=-3.5, swap=0.0, profit=-1.0, fee=0.0, symbol='EURUSD', comment='', external_id=''),
#  TradeDeal(ticket=112436932, order=158622912, time=1633397643, time_msc=1633397643495, type=0, entry=1, magic=0, position_id=158622890, reason=0, volume=1.0, price=1.162, commission=-3.5, swap=0.0, profit=-2.0, fee=0.0, symbol='EURUSD', comment='', external_id=''),
#  TradeDeal(ticket=112436933, order=158622918, time=1633397644, time_msc=1633397644310, type=0, entry=1, magic=0, position_id=158622888, reason=0, volume=1.0, price=1.162, commission=-3.5, swap=0.0, profit=-2.0, fee=0.0, symbol='EURUSD', comment='', external_id=''),
#  TradeDeal(ticket=112436947, order=158622935, time=1633397645, time_msc=1633397645952, type=0, entry=0, magic=0, position_id=158622935, reason=0, volume=1.0, price=1.16198, commission=-3.5, swap=0.0, profit=0.0, fee=0.0, symbol='EURUSD', comment='', external_id=''),
#  TradeDeal(ticket=112437850, order=158624328, time=1633398088, time_msc=1633398088672, type=1, entry=1, magic=0, position_id=158622935, reason=0, volume=1.0, price=1.16181, commission=-3.5, swap=0.0, profit=-17.0, fee=0.0, symbol='EURUSD', comment='', external_id=''),
#  TradeDeal(ticket=112438336, order=158625129, time=1633398768, time_msc=1633398768572, type=0, entry=0, magic=234000, position_id=158625129, reason=3, volume=2.0, price=1.16175, commission=-7.0, swap=0.0, profit=0.0, fee=0.0, symbol='EURUSD', comment='python script op', external_id=''),
#  TradeDeal(ticket=112438569, order=158625441, time=1633398962, time_msc=1633398962694, type=1, entry=1, magic=234000, position_id=158622885, reason=3, volume=1.0, price=1.16177, commission=-3.5, swap=0.0, profit=-22.0, fee=0.0, symbol='EURUSD', comment='python script op', external_id=''),
#  TradeDeal(ticket=112440282, order=158628089, time=1633400464, time_msc=1633400464589, type=0, entry=0, magic=0, position_id=158628089, reason=0, volume=1.0, price=1.1618, commission=-3.5, swap=0.0, profit=0.0, fee=0.0, symbol='EURUSD', comment='', external_id=''))

# %%
# send order to the market
# documentation: https://www.mql5.com/en/docs/integration/python_metatrader5/mt5ordersend_py

request = {
    "action": mt.TRADE_ACTION_DEAL,
    "symbol": "EURUSD",
    "volume": 2.0, # FLOAT
    "type": mt.ORDER_TYPE_BUY,
    "price": mt.symbol_info_tick("EURUSD").ask,
    "sl": 0.0, # FLOAT
    "tp": 0.0, # FLOAT
    "deviation": 20, # INTERGER
    "magic": 234000, # INTERGER
    "comment": "python script open",
    "type_time": mt.ORDER_TIME_GTC,
    "type_filling": mt.ORDER_FILLING_IOC,
}

order = mt.order_send(request)
print(order)
# Out:
# OrderSendResult(retcode=10009, deal=112442638, order=158631228, volume=2.0, price=1.1617, bid=1.1616900000000001, ask=1.1617, comment='Request executed', request_id=8, retcode_external=0, request=TradeRequest(action=1, magic=234000, order=0, symbol='EURUSD', volume=2.0, price=1.1617, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=0, type_filling=1, type_time=0, expiration=0, comment='python script open', position=0, position_by=0))

# %%
# close position

request = {
    "action": mt.TRADE_ACTION_DEAL,
    "symbol": "EURUSD",
    "volume": 2.0, # FLOAT
    "type": mt.ORDER_TYPE_SELL,
    "position": 158631228, # select the position you want to close
    "price": mt.symbol_info_tick("EURUSD").ask,
    "sl": 0.0, # FLOAT
    "tp": 0.0, # FLOAT
    "deviation": 20, # INTERGER
    "magic": 234000, # INTERGER
    "comment": "python script open",
    "type_time": mt.ORDER_TIME_GTC,
    "type_filling": mt.ORDER_FILLING_IOC,
}

order = mt.order_send(request)
print(order)
# Out:
# OrderSendResult(retcode=10009, deal=112442770, order=158631462, volume=2.0, price=1.16173, bid=1.16173, ask=1.16174, comment='Request executed', request_id=10, retcode_external=0, request=TradeRequest(action=1, magic=234000, order=0, symbol='EURUSD', volume=2.0, price=1.16174, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='python script open', position=158631228, position_by=0))
